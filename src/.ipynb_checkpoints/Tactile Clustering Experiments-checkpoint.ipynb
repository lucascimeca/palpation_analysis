# %% [markdown]
# ### Imports

# %%
from skin_data import (
    SkinData, 
    simulate_skin_data, 
    print_skin_data, 
    find_highest_pressure,
    apply_Knn,
    reorder_clusters,
    get_cluster_metrics
)
from tactile_objects import (
    TactileObjects,
    TactileObjectsTask
)
from experiment_setup import ExperimentSetup
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib nbagg

# %% [markdown]
# ### load data

# %%
exp_setup = ExperimentSetup("./../data/skin_experiments.mat", best_pressure_time=140)

# %%
exp_setup.run_experiment('3mil', which_clustering='k_means', show=True, save=True)
# Out:
# <img src="data:image/png;base64,..." width="935.5555803393147">
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %%
exp_setup.run_experiment('6mil', which_clustering='k_means', show=True, save=True)

# %%
exp_setup.run_experiment('10mil', which_clustering='k_means', show=True, save=True)

# %%
. skin = exp_setup.get_skin()
all_skin_data = skin.get_data() # dictionary

simulate_skin_data(all_skin_data['Cube_3mil_trial1'])

# %%
fig = plt.figure(figsize=(13, 8))
ax = fig.add_subplot(111)
ax.set_xlabel('$\\vec{p}_1$', fontsize=48)
ax.set_ylabel('$\\vec{p}_2$', fontsize=48)
line1, = plt.plot([3000,4000], [2000,1000], '--', label='aasfd', linewidth=2)
         
first_legend = plt.legend(handles=[line1], loc=2)

# Add the legend manually to the current Axes.
ax = plt.gca().add_artist(first_legend)
plt.show()

# %%
axes = plt.axis()
print(axes)

# %%
taskObj = exp_setup.get_taskObj()
cls_pairings = taskObj.get_class_pairings()

for key in cls_pairings.keys():
    print('{}:  {}'.format(key, cls_pairings[key]))

# %%
target_dict = exp_setup._get_targets(exp_setup.get_tasks())#

for key in target_dict.keys():
    print('{}:  {}'.format(key, target_dict[key]))
# exp_setup.run_experiment('10mil')

# %%
for task in exp_setup.get_tasks():
    print(task)

# %%
for experiment in exp_setup.get_experiments():
    print(experiment)

# %%
print(exp_setup.get_experiment_data_cls_pos())

# %%
exp_data = exp_setup.get_experiment_data()
for key in exp_data.keys():
    print('{}:  {}'.format(key, exp_data[key].shape))

# %%
color_dict = taskObj.get_color_dict()
for key in color_dict.keys():
    print('{}:  {}'.format(key, color_dict[key]))
